# %%
import pandas as pd
import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
from matplotlib import colors
import seaborn as sns

# %%
data = pd.read_csv('D:/kebakaran.csv',encoding='ISO-8859-1')
data.head()
# Out:
#    Unnamed: 0  No                    Tanggal     Keterangan JKB  \
# 0         NaN   1  01/Januari/2013  (Selasa)  Bencana Kebakaran
# 1         NaN   2  01/Januari/2013  (Selasa)  Bencana Kebakaran
# 2         NaN   3  01/Januari/2013  (Selasa)  Bencana Kebakaran
# 3         NaN   4  01/Januari/2013  (Selasa)  Bencana Kebakaran
# 4         NaN   5    02/Januari/2013  (Rabu)  Bencana Kebakaran
#
#         Sumber Informasi Waktu Informasi          Alamat Kejadian  RT    RW   \
# 0        Petugas Pemadam           00:05  Jl. Angin Puyuh No. 76C   5    11
# 1             Masyarakat           05:00              Jl. H. Alit   8     3
# 2             Masyarakat           10:00        Jl. Indra Loka VI   8     6
# 3  Petugas Instansi Lain           00:00    Jl. Jiung No.49 Gg. N   1     3
# 4        Petugas Pemadam           19:30         Jln. Meruya Raya   9     7
#
#         Kelurahan    ...     Objek BP Objek BUP Objek BI Objek KD Objek LN  \
# ...

# %%
data.shape
# Out:
# (1592, 45)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 45 columns):
# Unnamed: 0                        0 non-null float64
# No                                1592 non-null int64
# Tanggal                           1592 non-null object
# Keterangan JKB                    1592 non-null object
# Sumber Informasi                  1590 non-null object
# Waktu Informasi                   1592 non-null object
# Alamat Kejadian                   1592 non-null object
#  RT                               1095 non-null object
#  RW                               1112 non-null object
# Kelurahan                         1592 non-null object
# Kecamatan                         1592 non-null object
# Wilayah                           1592 non-null object
# Objek Kejadian Awal               1592 non-null object
# Kode Objek Bencana                1591 non-null object
# Kategori Objek Bencana            1591 non-null object
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0           No  JUMLAH UNIT   JUMLAH SDM  \
# count         0.0  1592.000000  1592.000000  1592.000000
# mean          NaN   796.500000     6.103015    30.214196
# std           NaN   459.715129     7.568215    37.357599
# min           NaN     1.000000     0.000000     0.000000
# 25%           NaN   398.750000     1.000000     5.000000
# 50%           NaN   796.500000     2.000000    12.000000
# 75%           NaN  1194.250000     9.000000    40.750000
# max           NaN  1592.000000    49.000000   254.000000
#
#        Lama Operasi -  Hari  Lama Operasi - Jam  Lama Operasi -  Menit  \
# count           1592.000000         1592.000000           1.592000e+03
# mean             -25.920854            2.410176          -3.730475e+04
# std             1034.765523            3.682834           1.490063e+06
# min           -41287.000000            0.000000          -5.945328e+07
# 25%                0.000000            0.000000           5.000000e+00
# ...

# %%
data.isna().any()
# Out:
# Unnamed: 0                         True
# No                                False
# Tanggal                           False
# Keterangan JKB                    False
# Sumber Informasi                   True
# Waktu Informasi                   False
# Alamat Kejadian                   False
#  RT                                True
#  RW                                True
# Kelurahan                         False
# Kecamatan                         False
# Wilayah                           False
# Objek Kejadian Awal               False
# Kode Objek Bencana                 True
# Kategori Objek Bencana             True
# Objek Kejadian Lainnya             True
# Kode Objek Bencana Lainnya         True
# Kategori Objek Bencana Lainnya     True
# ID Bang                            True
# Jenis Bangunan                     True
# ID Sebab                           True
# Sebab Kejadian                     True
# Keterangan Sebab Kejadian          True
# ...

# %%
data_baru=pd.DataFrame({'No':data['No'],
                        'Tanggal':data['Tanggal'],
                        'Keterangan JKB':data['Keterangan JKB'],
                        'Waktu Informasi':data['Waktu Informasi'],
                        'Alamat Kejadian':data['Alamat Kejadian'],
                        'Kelurahan':data['Kelurahan'],
                        'Kecamatan':data['Kecamatan'],
                        'Wilayah':data['Wilayah'],
                        'JUMLAH UNIT':data['JUMLAH UNIT'],
                        'JUMLAH SDM':data['JUMLAH SDM'],
                        'Lama Operasi -  Hari':data['Lama Operasi -  Hari'],
                        'Lama Operasi - Jam':data['Lama Operasi - Jam'],
                        'Lama Operasi -  Menit':data['Lama Operasi -  Menit'],
                        'Masyarakat Mati':data['Masyarakat Mati'],
                        'Objek Kejadian Awal':data['Objek Kejadian Awal'],
                        'Masyarakat Luka':data['Masyarakat Luka'],
                        'Petugas Mati':data['Petugas Mati'],
                        'Petugas  Luka':data['Petugas  Luka']})

data_baru
# Out:
#                                  Alamat Kejadian  JUMLAH SDM  JUMLAH UNIT  \
# 0                        Jl. Angin Puyuh No. 76C          60           12
# 1                                    Jl. H. Alit          10            2
# 2                              Jl. Indra Loka VI         120           24
# 3                          Jl. Jiung No.49 Gg. N          60           19
# 4                               Jln. Meruya Raya         100           20
# 5        Jln. Perum Kosambi Baru. Blok D.5 No. 5          70           14
# 6     Jln. Taman Palm Lestari Blok G.2 No. 21-22           5            1
# 7                        jl. Proyek senen blok 1          10            2
# 8                                Jl. Tawas  No.6          45            9
# 9                      Jl. Pecenongan Raya No. 8          64           14
# 10                       Jl. Inveksi Kali Grogol          45            9
# 11                                 Jl. Mandala 5         110           22
# ...

# %%
import scipy.stats
scipy.stats.norm
