# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('D:/jumlah _armada.csv')
df
# Out:
#              jenis_armada        merk  tahun_pengadaan  \
# 0   BUS KECIL ELF ( R.4 )       ISUZU             2012
# 1   BUS KECIL ELF ( R.4 )       ISUZU             2012
# 2   BUS KECIL ELF ( R.4 )       ISUZU             2012
# 3   BUS KECIL ELF ( R.4 )       ISUZU             2012
# 4   BUS KECIL ELF ( R.4 )       ISUZU             2012
# 5   BUS KECIL ELF ( R.4 )       ISUZU             2012
# 6   BUS KECIL ELF ( R.4 )       ISUZU             2012
# 7   BUS KECIL ELF ( R.4 )       ISUZU             2012
# 8   BUS KECIL ELF ( R.4 )       ISUZU             2012
# 9   BUS KECIL ELF ( R.4 )       ISUZU             2012
# 10  BUS KECIL ELF ( R.4 )       ISUZU             2012
# 11  BUS KECIL ELF ( R.4 )       ISUZU             2012
# 12  BUS KECIL ELF ( R.4 )       ISUZU             2012
# 13  BUS KECIL ELF ( R.4 )       ISUZU             2012
# 14  BUS KECIL ELF ( R.4 )       ISUZU             2012
# 15  BUS KECIL ELF ( R.4 )       ISUZU             2012
# ...

# %%
df['kondisi'].plot.bar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-7d0f258cc310> in <module>()
# ----> 1 df['kondisi'].plot.bar()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, **kwds)
#    2536         axes : matplotlib.AxesSubplot or np.array of them
#    2537         """
# -> 2538         return self(kind='bar', **kwds)
#    2539
#    2540     def barh(self, **kwds):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# ...

# %%
df1=pd.read_csv('D:/penumpang_bus.csv')
df1=df1.drop(df1.columns[5],axis=1)
df1
# Out:
#    type_operasi daerah_operasi  \
# 0        ZONASI         ZONA 1
# 1        ZONASI         ZONA 2
# 2        ZONASI         ZONA 3
# 3        ZONASI         ZONA 4
# 4        ZONASI         ZONA 5
# 5        ZONASI         ZONA 6
# 6        ZONASI         ZONA 7
# 7        ZONASI         ZONA 8
# 8        ZONASI         ZONA 9
# 9        ZONASI        ZONA 10
# 10       ZONASI        ZONA 11
# 11      REGULER         RUTE 1
# 12      REGULER         RUTE 2
# 13      REGULER         RUTE 3
# 14      REGULER         RUTE 4
# 15      REGULER        RUTE 4A
# 16      REGULER         RUTE 5
# 17      REGULER         RUTE 6
# 18      REGULER         RUTE 7
# 19      REGULER         RUTE 8
# 20      REGULER         RUTE 9
# 21      REGULER        RUTE 10
# 22      REGULER        RUTE 11
# 23      REGULER        RUTE 12
# 24      REGULER        RUTE 13
# 25      REGULER        RUTE 14
# 26      REGULER        RUTE 15
# 27      REGULER        RUTE 16
# 28      REGULER        RUTE 17
# ...

# %%
df3=pd.read_csv('D:/rute.csv')
df3
# Out:
#       jenis_rute nama_rute                                     rute  \
# 0   Rute Reguler    Rute 1   LAPANGAN BANTENG - PRINTIS KEMERDEKAAN
# 1   Rute Reguler    Rute 2            PLUMPANG - SUNTER - KEMAYORAN
# 2   Rute Reguler    Rute 3                          TMII - GANDARIA
# 3   Rute Reguler    Rute 4        PRINTIS KEMERDEKAAN - PONDOK KOPI
# 4   Rute Reguler    Rute 5                 TMII - TB.KAMPUNG MELAYU
# 5   Rute Reguler   Rute 6               KEBAYORAN - TB.PASAR MINGGU
# 6   Rute Reguler    Rute 7  TB.PASAR MINGGU - RANCO - LT.AGUNG - UI
# 7   Rute Reguler    Rute 8           TB.PASAR MINGGU - TB.MANGGARAI
# 8   Rute Reguler    Rute 9                        CAWANG - PLUMPANG
# 9   Rute Reguler   Rute 10          CILINCING - PRINTIS KEMERDEKAAN
# 10  Rute Reguler   Rute 11     TB.KAMPUNG MELAYU - LAPANGAN BANTENG
# 11  Rute Reguler   Rute 12                         BLOK M - CILEDUK
# 12  Rute Reguler   Rute 13         KALIDERES - GROGOL - GADJAH MADA
# ...

# %% [markdown]
# Cleaning

# %%
df.shape
# Out:
# (71, 8)

# %%
df1.shape
# Out:
# (30, 5)

# %%
df2.shape
# Out:
# (89, 2)

# %%
df3.shape
# Out:
# (24, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 8 columns):
# jenis_armada           71 non-null object
# merk                   71 non-null object
# tahun_pengadaan        71 non-null int64
# wilayah_operasi        71 non-null object
# nomor_plat             71 non-null object
# kondisi                71 non-null object
# kapasitas_penumpang    71 non-null object
# kode_trayek            71 non-null object
# dtypes: int64(1), object(7)
# memory usage: 4.5+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
# type_operasi        29 non-null object
# daerah_operasi      29 non-null object
# area_operasi        29 non-null object
# jumlah_bus          29 non-null float64
# jumlah_penumpang    29 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 1.2+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 2 columns):
# lokasi_halte       89 non-null object
# tahun_pembuatan    89 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 1.5+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 4 columns):
# jenis_rute       24 non-null object
# nama_rute        24 non-null object
# rute             24 non-null object
# jumlah_armada    24 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 848.0+ bytes

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
plt.scatter(x='jumlah_penumpang',y='jumlah_bus',data=df1,color='r',marker='o',s=30)
plt.show()

# %%
corr = df1.corr()
dfk = pd.DataFrame(df1.corr())
sns.heatmap(dfk, cmap='magma', linewidths=0.5, annot=True)
plt.show()

# %%
df1.describe()
# Out:
#        jumlah_bus  jumlah_penumpang  penumpang/bus
# count   29.000000         29.000000      29.000000
# mean    55.241379       7129.724138     285.188966
# std     17.126953       4521.224178     180.848967
# min     24.000000        105.000000       4.200000
# 25%     40.000000       3908.000000     156.320000
# 50%     52.000000       7447.000000     297.880000
# 75%     68.000000       8958.000000     358.320000
# max     99.000000      17901.000000     716.040000

# %%
df1['penumpang/bus']=df1['jumlah_penumpang']/35
df1['jumlah_bus_yang_dibutuhkan']=df1['penumpang/bus']
df1
# Out:
#    type_operasi daerah_operasi  \
# 0        ZONASI         ZONA 1
# 1        ZONASI         ZONA 2
# 2        ZONASI         ZONA 3
# 3        ZONASI         ZONA 4
# 4        ZONASI         ZONA 5
# 5        ZONASI         ZONA 6
# 6        ZONASI         ZONA 7
# 7        ZONASI         ZONA 8
# 8        ZONASI         ZONA 9
# 9        ZONASI        ZONA 10
# 10       ZONASI        ZONA 11
# 11      REGULER         RUTE 1
# 12      REGULER         RUTE 2
# 13      REGULER         RUTE 3
# 14      REGULER         RUTE 4
# 15      REGULER        RUTE 4A
# 16      REGULER         RUTE 5
# 17      REGULER         RUTE 6
# 18      REGULER         RUTE 7
# 19      REGULER         RUTE 8
# 20      REGULER         RUTE 9
# 21      REGULER        RUTE 10
# 22      REGULER        RUTE 11
# 23      REGULER        RUTE 12
# 24      REGULER        RUTE 13
# 25      REGULER        RUTE 14
# 26      REGULER        RUTE 15
# 27      REGULER        RUTE 16
# 28      REGULER        RUTE 17
# ...

# %%
df4=df1.drop(df1['jumlah_penumpang'],axis=1)
df4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-b59633584c34> in <module>()
# ----> 1 df4=df1.drop(df1['jumlah_penumpang'],axis=1)
#       2 df4
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
# ...
