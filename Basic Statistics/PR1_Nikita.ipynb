# %% [markdown]
# # PR PERTAMA

# %%
import pandas as pd
import numpy as np
import openpyxl as bi
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
import seaborn as sns

# %%
data=pd.read_csv('C:/Users/Nikita Dwie S/Documents/KERJA/PEER/No. 1/Creditability.csv', sep=',')
data.head()
# Out:
#    Creditability  Account.Balance  Duration.of.Credit  Previous.Credit  \
# 0              1                1                  18                4
# 1              1                1                   9                4
# 2              1                2                  12                2
# 3              1                1                  12                4
# 4              1                1                  12                4
#
#    Purpose  Credit.Amount  Value.Savings.Stocks  Length.of.current.employment  \
# 0        2           1049                     1                             2
# 1        0           2799                     1                             3
# 2        9            841                     2                             4
# 3        0           2122                     1                             3
# 4        0           2171                     1                             3
#
#    Instalment.per.income  Sex.Marital.Status       ...        \
# ...

# %% [markdown]
# # 1. paparan / insight / kalimat yang menggambarkan data

# %% [markdown]
# Sebelum melakukan pengolahan statistika deskriptif, data dibagi menjadi 4 jenis yaitu Nominal, Ordinal, Interval, Rasio

# %%
jenis=pd.read_csv( "C:/Users/Nikita Dwie S/Documents/KERJA/PEER/No. 1/jenis data.csv",sep=";" )
jenis
# Out:
#                         Variable     Jenis
# 0                  Creditability   Nominal
# 1                Account.Balance   Ordinal
# 2             Duration.of.Credit     Rasio
# 3                Previous.Credit   Ordinal
# 4                        Purpose   Nominal
# 5                  Credit.Amount     Rasio
# 6           Value.Savings.Stocks  interval
# 7   Length.of.current.employment  Interval
# 8          Instalment.per.income  Interval
# 9             Sex.Marital.Status   Nominal
# 10                    Guarantors   Ordinal
# 11   Duration.in.Current.address  interval
# 12           Most.valuable.asset   Ordinal
# 13                           Age     Rasio
# 14            Concurrent.Credits   Nominal
# 15             Type.of.apartment   Ordinal
# 16    No.of.Credits.at.this.Bank  interval
# 17                    Occupation   Ordinal
# 18              No.of.dependents  Interval
# 19                     Telephone   Nominal
# 20                Foreign.Worker   Nominal

# %%
data.shape
# Out:
# (900, 21)

# %% [markdown]
# dari program diatas kita mengetahui bahwa data memiliki jumlah bari 900 dan kolom sebanyak 21

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 21 columns):
# Creditability                   900 non-null int64
# Account.Balance                 900 non-null int64
# Duration.of.Credit              900 non-null int64
# Previous.Credit                 900 non-null int64
# Purpose                         900 non-null int64
# Credit.Amount                   900 non-null int64
# Value.Savings.Stocks            900 non-null int64
# Length.of.current.employment    900 non-null int64
# Instalment.per.income           900 non-null int64
# Sex.Marital.Status              900 non-null int64
# Guarantors                      900 non-null int64
# Duration.in.Current.address     900 non-null int64
# Most.valuable.asset             900 non-null int64
# Age                             900 non-null int64
# Concurrent.Credits              900 non-null int64
# Type.of.apartment               900 non-null int64
# ...

# %% [markdown]
# data creditability tidak mengandung missing value

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Creditability'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Creditability')
ax[0].set_ylabel('')
sns.countplot(x='Creditability',data=data,palette='GnBu_d')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Account.Balance'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Account.Balance')
ax[0].set_ylabel('')
sns.countplot(x='Account.Balance',data=data,palette='Blues')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Previous.Credit'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Previous.Credit')
ax[0].set_ylabel('')
sns.countplot(x='Previous.Credit',data=data,palette='BuGn_r')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Purpose'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Purpose')
ax[0].set_ylabel('')
sns.countplot(x='Purpose',data=data,palette='hls')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Value.Savings.Stocks'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Value.Savings.Stocks')
ax[0].set_ylabel('')
sns.countplot(x='Value.Savings.Stocks',data=data,palette='hls')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Length.of.current.employment'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Length.of.current.employment')
ax[0].set_ylabel('')
sns.countplot(x='Length.of.current.employment',data=data,palette='hls')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Instalment.per.income'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Instalment.per.income')
ax[0].set_ylabel('')
sns.countplot(x='Instalment.per.income',data=data,palette='hls')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Sex.Marital.Status'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Sex.Marital.Status')
ax[0].set_ylabel('')
sns.countplot(x='Sex.Marital.Status',data=data,palette='hls')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Guarantors'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Guarantors')
ax[0].set_ylabel('')
sns.countplot(x='Guarantors',data=data,palette='hls')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Duration.in.Current.address'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Duration.in.Current.address')
ax[0].set_ylabel('')
sns.countplot(x='Duration.in.Current.address',data=data,palette='hls')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Most.valuable.asset'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Most.valuable.asset')
ax[0].set_ylabel('')
sns.countplot(x='Most.valuable.asset',data=data,palette='hls')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Concurrent.Credits'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Concurrent.Credits')
ax[0].set_ylabel('')
sns.countplot(x='Concurrent.Credits',data=data,palette='hls')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Type.of.apartment'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Type.of.apartment')
ax[0].set_ylabel('')
sns.countplot(x='Type.of.apartment',data=data,palette='hls')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['No.of.Credits.at.this.Bank'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('No.of.Credits.at.this.Bank')
ax[0].set_ylabel('')
sns.countplot(x='No.of.Credits.at.this.Bank',data=data,palette='hls')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Occupation'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Occupation')
ax[0].set_ylabel('')
sns.countplot(x='Occupation',data=data,palette='hls')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['No.of.dependents'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('No.of.dependents')
ax[0].set_ylabel('')
sns.countplot(x='No.of.dependents',data=data,palette='hls')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Telephone'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Telephone')
ax[0].set_ylabel('')
sns.countplot(x='Telephone',data=data,palette='hls')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Foreign.Worker'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Foreign.Worker')
ax[0].set_ylabel('')
sns.countplot(x='Foreign.Worker',data=data,palette='hls')
plt.show()

# %% [markdown]
# Pembuatan bar chart dan pie chart dilakukan pada data kategorik untuk membandingkan frekuensi kategori 1 dan seterusnya pada masing masing variabel. untuk menambahkan insight kita dapat melihat perbandingan masing masing variabel berdasarkan status kredit (baik/buruk)

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('Account.Balance',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('Previous.Credit',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('Purpose',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('Value.Savings.Stocks',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('Length.of.current.employment',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('Instalment.per.income',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('Sex.Marital.Status',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('Guarantors',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()


f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('Duration.in.Current.address',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('Most.valuable.asset',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('Concurrent.Credits',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('Type.of.apartment',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('No.of.Credits.at.this.Bank',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('Occupation',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('No.of.dependents',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('Telephone',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()

f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot('Foreign.Worker',hue='Creditability',data=data,ax=ax[0])
ax[0].set_title('Credit Worthy vs Not-Credit Worthy')
plt.show()

# %% [markdown]
# Dari Boxplot yang dihasilkan kita tahu bahwa hanya variabel amount yang memiliki median hampir sama untuk pelanggan dengan status credit worthy dan not-credit worthy

# %%
pd.crosstab(data['Account.Balance'], [data['Creditability']], rownames=['Account.Balance'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_f7d7648f_50d3_11e8_a407_485ab65e33a8row0_col0 {
#
#                 background-color:  #96cb66;
#
#             }
#
#             #T_f7d7648f_50d3_11e8_a407_485ab65e33a8row0_col1 {
#
#                 background-color:  #dfef66;
#
#             }
#
#             #T_f7d7648f_50d3_11e8_a407_485ab65e33a8row0_col2 {
#
#                 background-color:  #c9e466;
#
#             }
#
#             #T_f7d7648f_50d3_11e8_a407_485ab65e33a8row1_col0 {
#
#                 background-color:  #b0d866;
#
#             }
#
#             #T_f7d7648f_50d3_11e8_a407_485ab65e33a8row1_col1 {
#
#                 background-color:  #d1e866;
#
#             }
#
#             #T_f7d7648f_50d3_11e8_a407_485ab65e33a8row1_col2 {
#
#                 background-color:  #c7e366;
#
#             }
#
#             #T_f7d7648f_50d3_11e8_a407_485ab65e33a8row2_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
# ...

# %%
pd.crosstab(data['Previous.Credit'], [data['Creditability']], rownames=['Previous.Credit'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_04a6338f_50d4_11e8_b24c_485ab65e33a8row0_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_04a6338f_50d4_11e8_b24c_485ab65e33a8row0_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_04a6338f_50d4_11e8_b24c_485ab65e33a8row0_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_04a6338f_50d4_11e8_b24c_485ab65e33a8row1_col0 {
#
#                 background-color:  #fcfe66;
#
#             }
#
#             #T_04a6338f_50d4_11e8_b24c_485ab65e33a8row1_col1 {
#
#                 background-color:  #fdfe66;
#
#             }
#
#             #T_04a6338f_50d4_11e8_b24c_485ab65e33a8row1_col2 {
#
#                 background-color:  #fdfe66;
#
#             }
#
#             #T_04a6338f_50d4_11e8_b24c_485ab65e33a8row2_col0 {
#
#                 background-color:  #78bc66;
#
#             }
#
# ...

# %%
pd.crosstab(data['Purpose'], [data['Creditability']], rownames=['Purpose'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_0dd4351e_50d4_11e8_aedc_485ab65e33a8row0_col0 {
#
#                 background-color:  #b7db66;
#
#             }
#
#             #T_0dd4351e_50d4_11e8_aedc_485ab65e33a8row0_col1 {
#
#                 background-color:  #cde666;
#
#             }
#
#             #T_0dd4351e_50d4_11e8_aedc_485ab65e33a8row0_col2 {
#
#                 background-color:  #c6e266;
#
#             }
#
#             #T_0dd4351e_50d4_11e8_aedc_485ab65e33a8row1_col0 {
#
#                 background-color:  #f1f866;
#
#             }
#
#             #T_0dd4351e_50d4_11e8_aedc_485ab65e33a8row1_col1 {
#
#                 background-color:  #e4f266;
#
#             }
#
#             #T_0dd4351e_50d4_11e8_aedc_485ab65e33a8row1_col2 {
#
#                 background-color:  #e8f466;
#
#             }
#
#             #T_0dd4351e_50d4_11e8_aedc_485ab65e33a8row2_col0 {
#
#                 background-color:  #cde666;
#
#             }
#
# ...

# %%
pd.crosstab(data['Value.Savings.Stocks'], [data['Creditability']], rownames=['Value.Savings.Stocks'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_14d01470_50d4_11e8_a326_485ab65e33a8row0_col0 {
#
#                 background-color:  #4ca666;
#
#             }
#
#             #T_14d01470_50d4_11e8_a326_485ab65e33a8row0_col1 {
#
#                 background-color:  #7abc66;
#
#             }
#
#             #T_14d01470_50d4_11e8_a326_485ab65e33a8row0_col2 {
#
#                 background-color:  #6cb666;
#
#             }
#
#             #T_14d01470_50d4_11e8_a326_485ab65e33a8row1_col0 {
#
#                 background-color:  #e6f266;
#
#             }
#
#             #T_14d01470_50d4_11e8_a326_485ab65e33a8row1_col1 {
#
#                 background-color:  #f5fa66;
#
#             }
#
#             #T_14d01470_50d4_11e8_a326_485ab65e33a8row1_col2 {
#
#                 background-color:  #f1f866;
#
#             }
#
#             #T_14d01470_50d4_11e8_a326_485ab65e33a8row2_col0 {
#
#                 background-color:  #fcfe66;
#
#             }
#
# ...

# %%
pd.crosstab(data['Length.of.current.employment'], [data['Creditability']], rownames=['Length.of.current.employment'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_1bc19380_50d4_11e8_ba19_485ab65e33a8row0_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_1bc19380_50d4_11e8_ba19_485ab65e33a8row0_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_1bc19380_50d4_11e8_ba19_485ab65e33a8row0_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_1bc19380_50d4_11e8_ba19_485ab65e33a8row1_col0 {
#
#                 background-color:  #d9ec66;
#
#             }
#
#             #T_1bc19380_50d4_11e8_ba19_485ab65e33a8row1_col1 {
#
#                 background-color:  #e5f266;
#
#             }
#
#             #T_1bc19380_50d4_11e8_ba19_485ab65e33a8row1_col2 {
#
#                 background-color:  #e1f066;
#
#             }
#
#             #T_1bc19380_50d4_11e8_ba19_485ab65e33a8row2_col0 {
#
#                 background-color:  #b5da66;
#
#             }
#
# ...

# %%
pd.crosstab(data['Instalment.per.income'], [data['Creditability']], rownames=['Instalment.per.income'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_224c135e_50d4_11e8_b3ff_485ab65e33a8row0_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_224c135e_50d4_11e8_b3ff_485ab65e33a8row0_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_224c135e_50d4_11e8_b3ff_485ab65e33a8row0_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_224c135e_50d4_11e8_b3ff_485ab65e33a8row1_col0 {
#
#                 background-color:  #e2f066;
#
#             }
#
#             #T_224c135e_50d4_11e8_b3ff_485ab65e33a8row1_col1 {
#
#                 background-color:  #e1f066;
#
#             }
#
#             #T_224c135e_50d4_11e8_b3ff_485ab65e33a8row1_col2 {
#
#                 background-color:  #e1f066;
#
#             }
#
#             #T_224c135e_50d4_11e8_b3ff_485ab65e33a8row2_col0 {
#
#                 background-color:  #f3f966;
#
#             }
#
# ...

# %%
pd.crosstab(data['Sex.Marital.Status'], [data['Creditability']], rownames=['Sex.Marital.Status'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_2843f02e_50d4_11e8_afd0_485ab65e33a8row0_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_2843f02e_50d4_11e8_afd0_485ab65e33a8row0_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_2843f02e_50d4_11e8_afd0_485ab65e33a8row0_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_2843f02e_50d4_11e8_afd0_485ab65e33a8row1_col0 {
#
#                 background-color:  #afd766;
#
#             }
#
#             #T_2843f02e_50d4_11e8_afd0_485ab65e33a8row1_col1 {
#
#                 background-color:  #bdde66;
#
#             }
#
#             #T_2843f02e_50d4_11e8_afd0_485ab65e33a8row1_col2 {
#
#                 background-color:  #b9dc66;
#
#             }
#
#             #T_2843f02e_50d4_11e8_afd0_485ab65e33a8row2_col0 {
#
#                 background-color:  #8ac466;
#
#             }
#
# ...

# %%
pd.crosstab(data['Guarantors'], [data['Creditability']], rownames=['Guarantors'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_2f622491_50d4_11e8_b541_485ab65e33a8row0_col0 {
#
#                 background-color:  #198c66;
#
#             }
#
#             #T_2f622491_50d4_11e8_b541_485ab65e33a8row0_col1 {
#
#                 background-color:  #188c66;
#
#             }
#
#             #T_2f622491_50d4_11e8_b541_485ab65e33a8row0_col2 {
#
#                 background-color:  #188c66;
#
#             }
#
#             #T_2f622491_50d4_11e8_b541_485ab65e33a8row1_col0 {
#
#                 background-color:  #f8fc66;
#
#             }
#
#             #T_2f622491_50d4_11e8_b541_485ab65e33a8row1_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_2f622491_50d4_11e8_b541_485ab65e33a8row1_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_2f622491_50d4_11e8_b541_485ab65e33a8row2_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
# ...

# %%
pd.crosstab(data['Duration.in.Current.address'], [data['Creditability']], rownames=['Duration.in.Current.address'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_35cfa68f_50d4_11e8_9207_485ab65e33a8row0_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_35cfa68f_50d4_11e8_9207_485ab65e33a8row0_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_35cfa68f_50d4_11e8_9207_485ab65e33a8row0_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_35cfa68f_50d4_11e8_9207_485ab65e33a8row1_col0 {
#
#                 background-color:  #c5e266;
#
#             }
#
#             #T_35cfa68f_50d4_11e8_9207_485ab65e33a8row1_col1 {
#
#                 background-color:  #d0e866;
#
#             }
#
#             #T_35cfa68f_50d4_11e8_9207_485ab65e33a8row1_col2 {
#
#                 background-color:  #cce666;
#
#             }
#
#             #T_35cfa68f_50d4_11e8_9207_485ab65e33a8row2_col0 {
#
#                 background-color:  #f4fa66;
#
#             }
#
# ...

# %%
pd.crosstab(data['Most.valuable.asset'], [data['Creditability']], rownames=['Most.valuable.asset'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_3b4ab240_50d4_11e8_867b_485ab65e33a8row0_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_3b4ab240_50d4_11e8_867b_485ab65e33a8row0_col1 {
#
#                 background-color:  #c9e466;
#
#             }
#
#             #T_3b4ab240_50d4_11e8_867b_485ab65e33a8row0_col2 {
#
#                 background-color:  #daec66;
#
#             }
#
#             #T_3b4ab240_50d4_11e8_867b_485ab65e33a8row1_col0 {
#
#                 background-color:  #f8fc66;
#
#             }
#
#             #T_3b4ab240_50d4_11e8_867b_485ab65e33a8row1_col1 {
#
#                 background-color:  #e3f166;
#
#             }
#
#             #T_3b4ab240_50d4_11e8_867b_485ab65e33a8row1_col2 {
#
#                 background-color:  #ebf566;
#
#             }
#
#             #T_3b4ab240_50d4_11e8_867b_485ab65e33a8row2_col0 {
#
#                 background-color:  #cde666;
#
#             }
#
# ...

# %%
pd.crosstab(data['Concurrent.Credits'], [data['Creditability']], rownames=['Concurrent.Credits'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_3fff128f_50d4_11e8_a023_485ab65e33a8row0_col0 {
#
#                 background-color:  #ddee66;
#
#             }
#
#             #T_3fff128f_50d4_11e8_a023_485ab65e33a8row0_col1 {
#
#                 background-color:  #e8f466;
#
#             }
#
#             #T_3fff128f_50d4_11e8_a023_485ab65e33a8row0_col2 {
#
#                 background-color:  #e5f266;
#
#             }
#
#             #T_3fff128f_50d4_11e8_a023_485ab65e33a8row1_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_3fff128f_50d4_11e8_a023_485ab65e33a8row1_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_3fff128f_50d4_11e8_a023_485ab65e33a8row1_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_3fff128f_50d4_11e8_a023_485ab65e33a8row2_col0 {
#
#                 background-color:  #40a066;
#
#             }
#
# ...

# %%
pd.crosstab(data['Type.of.apartment'], [data['Creditability']], rownames=['Type.of.apartment'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_46645730_50d4_11e8_aaaf_485ab65e33a8row0_col0 {
#
#                 background-color:  #e3f166;
#
#             }
#
#             #T_46645730_50d4_11e8_aaaf_485ab65e33a8row0_col1 {
#
#                 background-color:  #eef666;
#
#             }
#
#             #T_46645730_50d4_11e8_aaaf_485ab65e33a8row0_col2 {
#
#                 background-color:  #eaf466;
#
#             }
#
#             #T_46645730_50d4_11e8_aaaf_485ab65e33a8row1_col0 {
#
#                 background-color:  #6db666;
#
#             }
#
#             #T_46645730_50d4_11e8_aaaf_485ab65e33a8row1_col1 {
#
#                 background-color:  #47a366;
#
#             }
#
#             #T_46645730_50d4_11e8_aaaf_485ab65e33a8row1_col2 {
#
#                 background-color:  #52a866;
#
#             }
#
#             #T_46645730_50d4_11e8_aaaf_485ab65e33a8row2_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
# ...

# %%
pd.crosstab(data['No.of.Credits.at.this.Bank'], [data['Creditability']], rownames=['No.of.Credits.at.this.Bank'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_4b8e83c0_50d4_11e8_8610_485ab65e33a8row0_col0 {
#
#                 background-color:  #55aa66;
#
#             }
#
#             #T_4b8e83c0_50d4_11e8_8610_485ab65e33a8row0_col1 {
#
#                 background-color:  #60b066;
#
#             }
#
#             #T_4b8e83c0_50d4_11e8_8610_485ab65e33a8row0_col2 {
#
#                 background-color:  #5dae66;
#
#             }
#
#             #T_4b8e83c0_50d4_11e8_8610_485ab65e33a8row1_col0 {
#
#                 background-color:  #b3d966;
#
#             }
#
#             #T_4b8e83c0_50d4_11e8_8610_485ab65e33a8row1_col1 {
#
#                 background-color:  #aad466;
#
#             }
#
#             #T_4b8e83c0_50d4_11e8_8610_485ab65e33a8row1_col2 {
#
#                 background-color:  #add666;
#
#             }
#
#             #T_4b8e83c0_50d4_11e8_8610_485ab65e33a8row2_col0 {
#
#                 background-color:  #fcfe66;
#
#             }
#
# ...

# %%
pd.crosstab(data['Occupation'], [data['Creditability']], rownames=['Occupation'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_53fdc930_50d4_11e8_9fd6_485ab65e33a8row0_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_53fdc930_50d4_11e8_9fd6_485ab65e33a8row0_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_53fdc930_50d4_11e8_9fd6_485ab65e33a8row0_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_53fdc930_50d4_11e8_9fd6_485ab65e33a8row1_col0 {
#
#                 background-color:  #d7eb66;
#
#             }
#
#             #T_53fdc930_50d4_11e8_9fd6_485ab65e33a8row1_col1 {
#
#                 background-color:  #d1e866;
#
#             }
#
#             #T_53fdc930_50d4_11e8_9fd6_485ab65e33a8row1_col2 {
#
#                 background-color:  #d3e966;
#
#             }
#
#             #T_53fdc930_50d4_11e8_9fd6_485ab65e33a8row2_col0 {
#
#                 background-color:  #61b066;
#
#             }
#
# ...

# %%
pd.crosstab(data['No.of.dependents'], [data['Creditability']], rownames=['No.of.dependents'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_5d1fbcd1_50d4_11e8_9bff_485ab65e33a8row0_col0 {
#
#                 background-color:  #2f9766;
#
#             }
#
#             #T_5d1fbcd1_50d4_11e8_9bff_485ab65e33a8row0_col1 {
#
#                 background-color:  #2c9666;
#
#             }
#
#             #T_5d1fbcd1_50d4_11e8_9bff_485ab65e33a8row0_col2 {
#
#                 background-color:  #2d9666;
#
#             }
#
#             #T_5d1fbcd1_50d4_11e8_9bff_485ab65e33a8row1_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_5d1fbcd1_50d4_11e8_9bff_485ab65e33a8row1_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_5d1fbcd1_50d4_11e8_9bff_485ab65e33a8row1_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_5d1fbcd1_50d4_11e8_9bff_485ab65e33a8row2_col0 {
#
#                 background-color:  #008066;
#
#             }
#
# ...

# %%
pd.crosstab(data['Telephone'], [data['Creditability']], rownames=['Telephone'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_645ceae1_50d4_11e8_8a11_485ab65e33a8row0_col0 {
#
#                 background-color:  #9bcd66;
#
#             }
#
#             #T_645ceae1_50d4_11e8_8a11_485ab65e33a8row0_col1 {
#
#                 background-color:  #b9dc66;
#
#             }
#
#             #T_645ceae1_50d4_11e8_8a11_485ab65e33a8row0_col2 {
#
#                 background-color:  #b0d866;
#
#             }
#
#             #T_645ceae1_50d4_11e8_8a11_485ab65e33a8row1_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_645ceae1_50d4_11e8_8a11_485ab65e33a8row1_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_645ceae1_50d4_11e8_8a11_485ab65e33a8row1_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_645ceae1_50d4_11e8_8a11_485ab65e33a8row2_col0 {
#
#                 background-color:  #008066;
#
#             }
#
# ...

# %%
pd.crosstab(data['Foreign.Worker'], [data['Creditability']], rownames=['Foreign.Worker'], 
            colnames=['Creditability'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
#         <style  type="text/css" >
#
#
#             #T_67188870_50d4_11e8_90f7_485ab65e33a8row0_col0 {
#
#                 background-color:  #018066;
#
#             }
#
#             #T_67188870_50d4_11e8_90f7_485ab65e33a8row0_col1 {
#
#                 background-color:  #0a8466;
#
#             }
#
#             #T_67188870_50d4_11e8_90f7_485ab65e33a8row0_col2 {
#
#                 background-color:  #078366;
#
#             }
#
#             #T_67188870_50d4_11e8_90f7_485ab65e33a8row1_col0 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_67188870_50d4_11e8_90f7_485ab65e33a8row1_col1 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_67188870_50d4_11e8_90f7_485ab65e33a8row1_col2 {
#
#                 background-color:  #ffff66;
#
#             }
#
#             #T_67188870_50d4_11e8_90f7_485ab65e33a8row2_col0 {
#
#                 background-color:  #008066;
#
#             }
#
# ...

# %%
boxplot_class = pd.melt(data,id_vars=['Creditability'],value_vars=['Duration.of.Credit'], var_name='Duration.of.Credit')
sns.boxplot(x = 'Duration.of.Credit', y = 'value', data = boxplot_class ,hue='Creditability')
plt.show()

boxplot_class = pd.melt(data,id_vars=['Creditability'],value_vars=['Credit.Amount'], var_name='Credit.Amount')
sns.boxplot(x = 'Credit.Amount', y = 'value', data = boxplot_class ,hue='Creditability')
plt.show()

boxplot_class = pd.melt(data,id_vars=['Creditability'],value_vars=['Age'], var_name='Age')
sns.boxplot(x = 'Age', y = 'value', data = boxplot_class ,hue='Creditability')
plt.show()

# %%
data.describe()
# Out:
#        Creditability  Account.Balance  Duration.of.Credit  Previous.Credit  \
# count     900.000000       900.000000          900.000000       900.000000
# mean        0.700000         2.606667           21.124444         2.548889
# std         0.458512         1.254474           12.197579         1.077038
# min         0.000000         1.000000            4.000000         0.000000
# 25%         0.000000         1.000000           12.000000         2.000000
# 50%         1.000000         2.000000           18.000000         2.000000
# 75%         1.000000         4.000000           24.000000         4.000000
# max         1.000000         4.000000           72.000000         4.000000
#
#           Purpose  Credit.Amount  Value.Savings.Stocks  \
# count  900.000000     900.000000            900.000000
# mean     2.821111    3262.438889              2.117778
# std      2.716529    2849.866173              1.582551
# min      0.000000     250.000000              1.000000
# ...

# %%
kategorik1= data.drop('Duration.of.Credit', axis=1)
kategorik2=kategorik1.drop('Credit.Amount', axis=1)
kategorik=kategorik2.drop('Age', axis=1)
kategorik.head()
# Out:
#    Creditability  Account.Balance  Previous.Credit  Purpose  \
# 0              1                1                4        2
# 1              1                1                4        0
# 2              1                2                2        9
# 3              1                1                4        0
# 4              1                1                4        0
#
#    Value.Savings.Stocks  Length.of.current.employment  Instalment.per.income  \
# 0                     1                             2                      4
# 1                     1                             3                      2
# 2                     2                             4                      2
# 3                     1                             3                      3
# 4                     1                             3                      4
#
#    Sex.Marital.Status  Guarantors  Duration.in.Current.address  \
# 0                   2           1                            4
# ...

# %%
kategorik.mode()
# Out:
#    Creditability  Account.Balance  Previous.Credit  Purpose  \
# 0              1                4                2        3
#
#    Value.Savings.Stocks  Length.of.current.employment  Instalment.per.income  \
# 0                     1                             3                      4
#
#    Sex.Marital.Status  Guarantors  Duration.in.Current.address  \
# 0                   3           1                            4
#
#    Most.valuable.asset  Concurrent.Credits  Type.of.apartment  \
# 0                    3                   3                  2
#
#    No.of.Credits.at.this.Bank  Occupation  No.of.dependents  Telephone  \
# 0                           1           3                 1          1
#
#    Foreign.Worker
# 0               1

# %% [markdown]
# untuk mengetahui statistika deskriptif lebih lanjut kita dapat fokus pada data berjenis rasio, karena untuk data nominal, ordinal, dan interval lebih baik melihat nilai modusnya

# %%
import numpy as np
import matplotlib.pyplot as plt

x =data['Duration.of.Credit']
plt.hist(x)
plt.show()
x =data['Credit.Amount']
plt.hist(x)
plt.show()
x =data['Age']
plt.hist(x)
plt.show()

# %% [markdown]
# dapat dilihat dari ketiga histogram bahwa baik variabel durasi, jumlah amount, maupun umur pelanggan tidak berdistribusi normal, atau skew ke kanan, sehingga seperti yang digambarkan pada boxplot, terdapat outliers atas pada ketiga variabel tersebut

# %%
corr = data.corr()
sns.heatmap(data.corr())
plt.show()

# %% [markdown]
# # Tambahan

# %% [markdown]
# dari statstika deskriptif kita dapat mengetahui bahwa data ini dapat dianalisa menggunakan regresi logistik untuk memodelkan seseorang dengan status baik maupun buruk

# %%
from sklearn.utils import shuffle
random=shuffle(data)
random_1=random[:int((len(random)+1)*.70)] #untuk membentuk model perlu dilakukan split training dan testing data
random_2=random[int(len(random)*.70+1):] #digunakan 70%:30%

x_train = random_1.drop('Creditability', axis=1) #data training
y_train = random_1['Creditability']

x_test = random_2.drop('Creditability', axis=1) #data test
y_test = random_2['Creditability']

#model regresi logistik
import statsmodels.api as sm
logit_model=sm.Logit(y_train, x_train)
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.505248
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:          Creditability   No. Observations:                  630
# Model:                          Logit   Df Residuals:                      610
# Method:                           MLE   Df Model:                           19
# Date:                Sun, 06 May 2018   Pseudo R-squ.:                  0.1899
# Time:                        16:03:22   Log-Likelihood:                -318.31
# converged:                       True   LL-Null:                       -392.94
#                                         LLR p-value:                 3.025e-22
# ...
#                                    coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logreg = LogisticRegression()
logreg.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = logreg.predict(x_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(x_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.80

# %%
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
kfold = model_selection.KFold(n_splits=10, random_state=7)
modelCV = LogisticRegression()
scoring = 'accuracy'
results = model_selection.cross_val_score(modelCV, x_train, y_train, cv=kfold, scoring=scoring)
print("10-fold cross validation average accuracy: %.3f" % (results.mean()))
# Out:
# 10-fold cross validation average accuracy: 0.725

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.64      0.51      0.57        71
#           1       0.84      0.90      0.87       198
#
# avg / total       0.78      0.80      0.79       269

# %% [markdown]
# dari summary diatas kita dapat menentukan variabel prediktor yang berpengaruh signifikan terhadap respon merupakan viarbel yang memiliki nilai P>|z| lebih kecil dari alpha atau 0.05. akan lebih baik jika sebelum pembuatan model dilakukan terlebih dahulu feature selection karena nilai akurasi yang dihasilkan hanya sekitar 72-80% sehingga model masih belum akurat

# %% [markdown]
# # 2. Bootstrap untuk menguji hipotesis

# %%
#mengambil data berdasarkan kategori yang diinginkan
baik = data[data['Account.Balance']==4]
buruk = data[data['Account.Balance']!=4]

#mengambil data dari variabel yang akan diuji
baik1 =baik['Creditability']
buruk1 = baik['Creditability']

good= np.array(baik1)
bad = np.array(buruk1)


#melakukan resampling
def bootstrap_resample(A, n=None):
    if n == None:
        n = len(A)
    np.random.seed(8)    
    resample_i = np.floor(np.random.rand(n)*len(A)).astype(int)
    resample = A[resample_i]
    return resample

baik_resample = bootstrap_resample(good, n=10000)
buruk_resample = bootstrap_resample(bad, n=10000)

# %%
good_bootstrap=[]
for i in range(10000):
    result_resample = bootstrap_resample(baik_resample,n=363)
    m=result_resample.mean()
    good_bootstrap.append(m)
good_bootstrap = np.array(good_bootstrap)
good_bootstrap.mean()
# Out:
# 0.88980716253443515

# %%
bad_bootstrap=[]
for i in range(10000):
    result_resample = bootstrap_resample(buruk_resample,n=537)
    m=result_resample.mean()
    bad_bootstrap.append(m)
bad_bootstrap = np.array(bad_bootstrap)
bad_bootstrap.mean()
# Out:
# 0.90502793296089434

# %%
import scipy.stats as ss
ss.ttest_ind(good_bootstrap,bad_bootstrap)
# Out:
# Ttest_indResult(statistic=-3324912565737848.0, pvalue=0.0)

# %% [markdown]
# Pada statistika inferensia ini akan dibuktikan bahwa orang-orang yang mempunyai Saldo (Account.Balance) ≥ 200 USD memiliki tingkat credibility 25% lebih tinggi daripada orang lainnya (tidak punya akun, tidak punya saldo dan saldo kurang dari 200 USD) menggunakan metode resampling dengan hipotesis sebagai berikut
# H0:orang yang mempunyai saldo => 200 USD memiliki tingkat credibility 25% <= dari orang lainnya
# H1:orang yang mempunyai saldo => 200 USD memiliki tingkat credibility 25% > dari orang lainnya
#
# Statistika uji: P-value (0.0) < alfa (0.05)
# keputusan: tolak H0
# Kesimpulan: terbukti bahwa orang-orang yang mempunyai saldo >=200USDmemiliki tigkat credibility 25% lebih besar dari yang lainnya

# %% [markdown]
# # 3. Statistika Inferensia Untuk Menguji Hipotesis

# %% [markdown]
# Pada bagian ini saya akan menguji apakah dua populasi baik pada variabel duration of credit, credit amount, dan age memiliki perbedaan untuk pelanggan dengan status credit worthy maupun not-credit worthy

# %%
x1 = data[data['Creditability'] == 0]['Duration.of.Credit']
x2 = data[data['Creditability'] == 1]['Duration.of.Credit']
import numpy as np
import statsmodels.api as sm
from scipy import stats
import statsmodels.formula.api as smf
sm.stats.ztest(x1, x2, value=0, alternative='two-sided', usevar='pooled', ddof=1.0)
# Out:
# (7.0110535637163132, 2.3653015199711729e-12)

# %% [markdown]
# Untuk pengujian pertama digunakan z test karena jumlah data yang cukup banyak. dari pengujian ini kita akan mencari tau apakah rata-rata Durasi kredit pelanggan dengan status baik sama dengan rata-rata Durasi kredit pelanggan dengan status buruk dengan menggunakan hipotesis
#
# H0: rata-rata Durasi kredit pelanggan berstatus baik = rata-rata Durasi kredit pelanggan berstatus buruk
# H1: rata-rata Durasi kredit pelanggan berstatus baik != rata-rata Durasi kredit pelanggan berstatus buruk
#
# Uji statistik : nilai pvalue= 2.365 x 10^-12<alpha=0.05
#
# Keputusan: Tolak H0
# Kesimpulan: Rata-rata Durasi kredit pelanggan berstatus baik tidak sama dengan rata-rata Durasi kredit pelanggan berstatus buruk

# %%
x1 = data[data['Creditability'] == 0]['Credit.Amount']
x2 = data[data['Creditability'] == 1]['Credit.Amount']
import numpy as np
import statsmodels.api as sm
from scipy import stats
import statsmodels.formula.api as smf
sm.stats.ztest(x1, x2, value=0, alternative='two-sided', usevar='pooled', ddof=1.0)
# Out:
# (5.1381770827618753, 2.7741640191166185e-07)

# %% [markdown]
# Pada pengujian ini kita akan mencari tau apakah rata-rata Jumlah Kredit pelanggan dengan status baik sama dengan rata-rata Jumlah Kredit pelanggan dengan status buruk dengan menggunakan hipotesis
#
# H0: rata-rata Jumlah Kredit pelanggan berstatus baik = rata-rata Jumlah Kredit pelanggan berstatus buruk
# H1: rata-rata Jumlah Kredit pelanggan berstatus baik != rata-rata Jumlah Kredit pelanggan berstatus buruk
#
# Uji statistik : nilai pvalue= 2.77 x 10^-7<alpha=0.05
#
# Keputusan: Tolak H0
# Kesimpulan: Rata-rata untuk Jumlah Kredit pelanggan berstatus baik tidak sama dengan rata-rata Jumlah Kredit pelanggan berstatus buruk

# %%
x1 = data[data['Creditability'] == 0]['Age']
x2 = data[data['Creditability'] == 1]['Age']
import numpy as np
import statsmodels.api as sm
from scipy import stats
import statsmodels.formula.api as smf
sm.stats.ztest(x1, x2, value=0, alternative='two-sided', usevar='pooled', ddof=1.0)
# Out:
# (-2.7353474882020263, 0.0062314455202512583)

# %% [markdown]
# Pada pengujian ini kita akan mencari tau apakah rata-rata Umur pelanggan dengan status baik sama dengan rata-rata Umur pelanggan dengan status buruk dengan menggunakan hipotesis
#
# H0: rata-rata Umur pelanggan berstatus baik = rata-rata Umur pelanggan berstatus buruk
# H1: rata-rata Umur pelanggan berstatus baik != rata-rata Umur pelanggan berstatus buruk
#
# Uji statistik : nilai pvalue= 0.006<alpha=0.05
#
# Keputusan: Tolak H0
# Kesimpulan: Rata-rata untuk Umur pelanggan berstatus baik tidak sama dengan rata-rata Umur pelanggan berstatus buruk

# %% [markdown]
# # Dari ketiga pengujian terhadap data rasio kita dapat mengetahui bahwa dari kesimpulan bahwa rata-rata dari masing-masing kategori, ketiga variabel bukanlah penentu utama seseorang dikatakan good (credit worthy) atau bad (not-credit worthy)
